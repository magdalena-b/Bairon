# %% [markdown]
# <a href="https://colab.research.google.com/github/magdalena-b/BAIron/blob/master/cummings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install tensorflow==1.13.2
# !pip install -q gpt-2-simple
# Out:
# ...
#      |████████████████████████████████| 2.3MB 5.3MB/s
# ...
#      |████████████████████████████████| 3.3MB 33.3MB/s
# ...
#      |████████████████████████████████| 901kB 41.1MB/s
# ...
#      |████████████████████████████████| 92.7MB 60kB/s
# ...
#      |████████████████████████████████| 51kB 6.6MB/s
# ...
#      |████████████████████████████████| 3.2MB 36.9MB/s
# ...
#      |████████████████████████████████| 368kB 49.8MB/s
# ...
# ERROR: kapre 0.3.5 has requirement tensorflow>=2.0.0, but you'll have tensorflow 1.13.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# ...

# %%
import transformers
import gpt_2_simple as gpt2
import tensorflow
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from google.colab import files

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-259a0b11-c91f-4080-a7f7-029996d7a0ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-259a0b11-c91f-4080-a7f7-029996d7a0ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cummings.txt to cummings.txt

# %%
data_file = "cummings.txt"

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 199Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 9.33Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 342Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [01:06, 7.51Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 257Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 9.98Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 8.61Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
tensorflow.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
          steps=150,
          dataset=data_file,
          model_name='124M', 
          print_every=5,
          run_name= 'cummings2',
          restore_from='latest',
          sample_every=10,
          save_every=10
          )
# Out:
# Loading checkpoint checkpoint/cummings2/model-45
# INFO:tensorflow:Restoring parameters from checkpoint/cummings2/model-45
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# dataset has 27635 tokens
# Training...
# [50 | 868.35] loss=2.53 avg=2.53
# Saving checkpoint/cummings2/model-50
# ======== SAMPLE 1 ========
#  face of my eyes
# (while others stare;and that very day
# —to-night
# of you i will stand
# in the sunset—and will sing
# your miraculous song
# (to men)
#
# invisible hours lie waiting
# in the dark;and here shall come your smile
#
# or shall we stand
#
# in the dark?
#
#
# (in the morning
# stand thou
#
# (in the afternoon
# stand thou
# (after dawn)stand
#
#
# (one after another
# stands
#
# one for the whole day
# stands
# one for the moment
#
# stands
# a thousand times between
# these
#
# which have not ceased
#
# one thing or another—
# sleep
# (or thou wilt surely be nigh
# in time to come)
#
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='cummings2')

# %%
gpt2.generate(sess, run_name='cummings2', prefix = "Life as it is", length = 200)
# Out:
# Life as it is,
# O let
# the rain be anointing
# her
# with veils,
#
# O
# the incense be
# with life be
#
# it shall be
# when thou shalt have seen
# thy mirror
#
# the naked woman
# twelve
# feet
# behind
# him
# repentance shall
#
# is
# breath
# fruit
# fruit of thy
# sleep
#
#
# if this were
# happen to thee,
# raise thee
# thy head
# and find
# thy eye
# repentless
# lips
#
#
# if this were
# happen to thee,
# raise thy
# limb
# and find
# thy breath
# repentless
# lips
#
#
# if this were
# happen to thee,
# raise
# thy face
# and find
# thy hair
# repentless
#
# jewels
#
#
# if this were
# happen to thee,
# raise
# thy face
# and find
# thy hair
# repentless
# chisel
