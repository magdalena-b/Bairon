# %% [markdown]
# <a href="https://colab.research.google.com/github/magdalena-b/BAIron/blob/master/cummings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install tensorflow==1.13.2
# !pip install -q gpt-2-simple
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/b0/9e/5b80becd952d5f7250eaf8fc64b957077b12ccfe73e9c03d37146ab29712/transformers-4.6.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 7.8MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 45.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 39.4MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (8.0.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.2 transformers-4.6.0
# Collecting tensorflow==1.13.2
#   Downloading https://files.pythonhosted.org/packages/bc/70/45d3b9fab768215a2055c7819d39547a4b0b7401b4583094068741aff99b/tensorflow-1.13.2-cp37-cp37m-manylinux1_x86_64.whl (92.7MB)
#      |████████████████████████████████| 92.7MB 46kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.3.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.32.0)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.15.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (3.12.4)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 34.3MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.36.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.19.5)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.8.1)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
#      |████████████████████████████████| 368kB 45.0MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.2) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.13.2) (56.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (2.0.0)
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/5c/03/b7e605db4a57c0f6fba744b11ef3ddf4ddebcada35022927a2b5fc623fdf/mock-4.0.3-py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.7.4.3)
# Installing collected packages: keras-applications, tensorboard, mock, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.2 tensorflow-estimator-1.13.0
#   Building wheel for gpt-2-simple (setup.py) ... done

# %%
import transformers
import gpt_2_simple as gpt2
import tensorflow
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from google.colab import files

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-29829435-8602-4d0d-9b73-1def62ebc992" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29829435-8602-4d0d-9b73-1def62ebc992">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cummings.txt to cummings.txt

# %%
data_file = "cummings.txt"

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 187Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.42Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 399Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:24, 20.1Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 289Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.90Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.98Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
tensorflow.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
          steps=50,
          dataset=data_file,
          model_name='124M', 
          print_every=5,
          run_name= 'cummings',
          restore_from='latest',
          sample_every=10,
          save_every=10
          )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Loading checkpoint models/124M/model.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# dataset has 27635 tokens
# Training...
# [5 | 797.53] loss=4.17 avg=4.17
# [10 | 1584.42] loss=3.40 avg=3.78
# Saving checkpoint/cummings/model-10
# ======== SAMPLE 1 ========
#  feel as if I have been put in a strange limbo, a world where my parents have moved into the home of their children. The old man of whom I know nothing, as if in one place, a world of the unspoken, the unseen.
#
# I am a child with a mind of mystery — the mind of dread. A world of chaos has been given the power to go into the world of unknown in spite of the power of the world it is meant to hide from the mind of mind; the mind of fear has been given the power to pretend to fly.
# The world is very mysterious. A world of a unknown unknown is the world of the unknown unknown.
# The world that is known was not a world of unknown unknown unknown. It was, a world of a mystery unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown unknown
# The world which is known is not a world who has the world of unknown unknown unknown unknown unknown unknown unknown
# But I shall find that this world is strange unknown.
# And so I shall find that this world is beyond my mind, so that it is within my heart.
# the girl who loved him, and
# every thought of him were
# my first thought when I was dead was
# something in this little mouth,
# but the girl felt a cold touch of
# blood on my lips as she looked in
# the face of her dead body before her
#
#
# my face caught the cold,and suddenly the
# blood was so cold and
# my brain was on a piece
# of ice
# with a feeling as the girl
# had lost something that she had loved.
#
# The last of a very strange sort of
# unbelievable,
# the last of a very strange
# kind of beautifully,
# the last of a very mysterious
#
# kind of strange
#
# but,there were still more people than the
#
# girls to play
# the music
# the song that had touched my heart
#
# the song that my sister used to sing,
#
# the song that my sister loved to sing,
# the song
# that the love of my sister was
# her voice was so close and
# like her a smile touched upon
# my heart,my feet
# with the sound of my heart
# she spoke softly before
# my heart and the way of the rain
#
#
#
#
#
# The sun
#
# for the earth
# for heaven
#
#
# my feet did not forget
# my feet,my feet did not forget
# my feet.
# They would run
# but the thing who ran
# him was gone.The
# things that went
# him in the way whereof
# her lips
# did not forget her.For
# the earth
# with her lips,of her fingers
# did not forget her.For
#
# the world
# with her
# as the hand of an unhealed
# man did not forget her.
# The flowers of the world
# were gone in the way
# whereofher lips
# did not forget her.
# For
# the world
# was gone in the way,the world said
#
# to the world.
#
# It did not,because,for
# the hands of death and the hands of life
# and wherefore,there,
#
# with the fingers of death
# made a world,a world
# like of roses.
#
# But the hand of death did not forget her,
# because
# the hand of death
# did not forget her.
# When they spoke,
# the world came to them and said,
#
# we came because of love
# and love because of something that is
#
# something to whom you take a dear.
# The world came to them
# and said,
# we came because of love
# and love because of something that is
# something to whom you take a
# little.
# When they spoke,the world came to them
# and said,
# you would come because of love.
#
# Then it came to them and said,
# you would come because…something
# (sadness in your mouth):
# something that is important.
# You always thought of me,and always thought of
# you when you came and did not forget the things
# that mattered.
# When the world came to them,
# love,love,loved you
# and did not forget the things….you
# were the world.
# And the world came to you.
# Love,love,love,loved you….when you touched it
# with love
# love
# love
# love
# love,love,loved you….when you pressed your fingers against the
# little
#
# little
# little
# little
# little
#
# little
# little
# little
# little
# little
# little
# old smile in the room where
# the room which is her
# little
# little
# little
# little
# little
# little
# little
#
# little
#
# little
# little
# little
# little)
# the little world
# the world,
#
#
# (The little world)
# which is love,
# which is love,
# which is love and
# which is love because
#
# something where
# some
# of you are,and it
# (something somewhere
# of you)
# or maybe
#
#
# if someone tells me
# that
# the little world
# is an
# the
# little little world,and
# something where
# some
# of you are
# and that
# something
# wheresomeof you are
#
#
# [25 | 4185.10] loss=3.19 avg=3.55
# [30 | 4974.97] loss=3.30 avg=3.50
# Saving checkpoint/cummings/model-30
# ======== SAMPLE 1 ========
#  love.
# And if anything, as you are the most beautiful thing
#
# yet in whose mouth were we so proud?
# You have loved me, and yet you
# excealed all my beauty.
# But what if the love of my mind could have
# only been
# wonderful before?
#
# Whose mouth was our smile?
# But who should we be?
# Or for that we should love one another,
# and that the more we love each other,
# the less we shall love you,
# or the worse, as all the hearts of animals and
# people have loved each other,
# we shall not be afraid; for, as we love we will
# not have to love each other,nor do we want
#
#
# each one of us to take the chance of something truly wonderful
# just because we are afraid.
# But if nothing, as your own eyes believe,
# the more my heart, as mine has love,
# then should we not be afraid,
# just because we love each other and we feel afraid?
# And if anything, as your eyes believe,
# your own mind should
# feel afraid,because,as mine has loved and we are afraid,
# why is it that if anything be afraid?
#
# Then should not your own mind,whose eyes have love and
# feel afraid,do you have any desire to be afraid
# of anything?
# And is that not why we should love eachother?
#
# Well,my dear boy—
# because if anything be afraid of
# you,why is it that if anything be afraid of,and if anything be afraid of,i
# take away anything from you at a certain time,
# the world does not see you as you want you to,the world
#
# would not see you as you love you;
#
# i would do what you loved me to do,
# it is precisely because nothing is
# unbelievable that you should want anything.
#
# So,my dear boy—as you have loved and I loved—
#
# the earth does not perceive you as you want you to do
#
# because everything is beyond understanding.
#
# I say unto you what are your eyes?
#
# Look,what are their eyes?and what are their mouths?
# O my boy
# whose eyes are like the rain and who,at the
# flowering moon
#
# are like the sea:
#
#
# why is this?because the
# water
# hurts;
#
# and the moon
# hurts.
# O my boy!O my boy
# thy mouth is like the rain,
# or the moon!
# the moon
# hurts,
# O my boy,thy mouth is like the rain,
# or the sea!
# the tide
# hurts,O my boy,thy mouth is like the rain,
# or the dawn!
#
# O my boy!
# thy mouth is like the moon;
# the moon
# hurts,O my boy?s mouth is like the moon;
# the moon—hurts,O my boy,thy mouth is like the moon,
# (or the dawn)
# O my boy!
# thy mouth is like the sea.
#
# thy body,thy mouth
# hast thou
# hast thou taken from thy mouth
# the earth and the sea?
# whose bodies and hands are like the moon?
# thy bodies are like the rain,
# whose bodies and hands are like the moon?
# thy hands are like the rain,
# whose hands and feet are like the moon?
# thy feet are like the moon!
# thy feet are like the sea!
# thy neck is like the moon!
# thy waist is like the rain;
# thy stomach is like the earth;
# thy diaphragm is like the sky;
# thy head is like the rain;
# thy right eye is like the moon;
# thy left breast is like the sky;
# thy right eye is like the rain;
# thy left thigh is like the moon?
# thy hips are like the moon?
# thy legs are like the rain;
# thy ankles are like the rain;
# thy knees are like the moon;
# thy hips are like the moon;
# thy lats are like the rain;
# thy calves are like the star
# to whom is life;
# thy thighs are like the moon
# to whom is life;
# thy lips are like the star
# to what is hell?to whom is death;
# thy mouth is like the moon;to whom is
#
# world,
# to whom is death;
#
# holly eyes have death;
# heavens has death;
#
# unforgivable things
#
# and you
# have been made a god,for it was said,
# God loved the world and loved the world for he loved
# him and she loved him for who shall take his flesh away From
# him and from them come the stars which shall not be known, for when the star
# will pass away,
# the stars
#
# [35 | 5879.61] loss=3.24 avg=3.46
# [40 | 6670.16] loss=3.50 avg=3.47
# Saving checkpoint/cummings/model-40
# ======== SAMPLE 1 ========
#  fascination for our country. She was like our little sister
# when she heard the noise of it and the
# hurry of its steps.
#
# I shall say, that,being called i
# have one flesh which is
# the hair of your head that i may eat
# it. i say to you:
#
# the people of your kingdom have come out of their days for the first time to sit by while we wait for their judgment
#
#
# and the people of your people have come so out
# in your lands to sit and stare
# into your eyes,their
# mouth in their eyes
# with this:you will not live
# again,nor will
# you be happy
# upon a snowy day….
#
# The people of your kingdom went through the sunset
# and did the day in the biggest
# hand of their souls
# that i might take them with me
#
# to his kingdom where is the prince
# of the houses whose hair dangles from his
# eyes a tree ripe with roses.
# ’i say to you:
# it is with my body that your kingdom is born
#
# and if we should have it,i would gladly take
# you with me to his kingdom
#
# which is the kingdom of sleep
# and in the twilight i have dreamed in my
# eye
#
# the kingdom of your lips….                                                                  how easily i may
# see through your dark eyes
# with what your beauty may bear i will
# simply give you with my hand
# a kiss on the mouth,
# and in the twilight in my eyes
#
# your life
#
# will most easily be
#
# someday
# i will have
# a dream
#
# you will feel the rain
#
# slowly killing the flowers and picking them
# out of the darkness….    My eyes
#
# will be all smiles and roses,
#
# and i will
#
# sleep
#
# a little,and i
# will dream with you the sky….
#
# dreaming
#
# little and crazy and everything
#
# the first day
# i dreamed to myself
# that in my dreams one
# dream i caught
#
# of your face your legs—and i
#
# saw
# and also
# the other day
# when you came to bed,
# little girls
# who are beautiful,my
# moon and
# a man
# girdle
# ’s legs
# O boys,how
# much more do i
# want to touch
# your body—and how much more do i care do i
# need
# to
# touch your feet—and to feel their skin—and,if
# you are
# good.’Truly
# god’s will,i’m thinking
# of all things,and thinking of all things
#
# and the world and i’ll
# get up in the morning
# and how this is,you say?
#
# (and i say)it’s very hard but
#
# because you were a hunter—and i
# belong to you
# and for having loved you.
#
# and because it’s nice to see you
# in your fuzzy old white summer
#
# and because when it’s raining
# it’s sunny
# and in the big window
#
#
# and as i am putting away my pencil
#
# (to which it says)
# you were quite a boy,only 11 with a
# big smile
# and his body was quite a boy
#
# And,when they were young and i was a
# smiling
# young boy and i had a dream
#
# i saw your body
# suddenly
# suddenly
# a man’s face—
# which i loved;
# and i am thinking to myself,
# in the cool darkness,
# (and i am thinking of how it all will
# make sense—if you come in sunlight
# and i
# smile deeply down at you.
# ’O boys,in this world!)
#       in the day—
# when the rain is on—and the big man sits in a seat
#
# he sits in a seat—he feels like he is in the rain
# and the rain is the weather!
# and the rain is killing
# you by the hour—and the big man sits
# in one seat
# and the earth is playing with time
# and the big man sits
#
# at the edge of his seat and the rain is
#
#  killing him by the mile—and the rain is killing
# you by the mile:
# and the moon is shining and the rain is killing
# you by the mile by day the rain:
# and the sky is falling and the rain is killing
# you with every breath.
# and the rain is killing you with every
#
# [45 | 7571.72] loss=3.05 avg=3.42
# [50 | 8359.98] loss=2.00 avg=3.27
# Saving checkpoint/cummings/model-50

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='cummings')

# %%
gpt2.generate(sess, run_name='cummings', prefix = "Life as it is", length = 200)
# Out:
# Life as it is.
#
# —The Black
#
# Dawn
# If you are thinking of killing me,use this:
#
# i will not lie with you
# in the dark like a moth
#
#
# but i will upon your face
#
# love
#
# and when you are asleep
#
# I will give you a kiss
# and when you are asleep
#
# I will give you a kiss upon my head
# and when you are asleep
# I will give you a kiss upon your head
# and when you are asleep
#
# I will give you a kiss upon your head the whole
# city of your eyes
# and when you are asleep
# I will give you a kiss upon your feet
# and when you are asleep
# I will give you a kiss upon your hands
# and when you are asleep
# I will leave you and go to sleep
# on your body like a great star
#
# and when you are asleep
# i will give you a kiss
# and when you are asleep
# I will give
